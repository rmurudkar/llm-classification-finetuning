# %%
import pandas as pd


df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#        id             model_a              model_b  \
# 0   30192  gpt-4-1106-preview           gpt-4-0613
# 1   53567           koala-13b           gpt-4-0613
# 2   65089  gpt-3.5-turbo-0613       mistral-medium
# 3   96401    llama-2-13b-chat  mistral-7b-instruct
# 4  198779           koala-13b   gpt-3.5-turbo-0314
#
#                                               prompt  \
# 0  ["Is it morally right to try to have a certain...
# 1  ["What is the difference between marriage lice...
# 2  ["explain function calling. how would you call...
# 3  ["How can I create a test set for a very rare ...
# 4  ["What is the best way to travel from Tel-Aviv...
#
#                                           response_a  \
# 0  ["The question of whether it is morally right ...
# 1  ["A marriage license is a legal document that ...
# 2  ["Function calling is the process of invoking ...
# 3  ["Creating a test set for a very rare category...
# 4  ["The best way to travel from Tel Aviv to Jeru...
#
# ...

# %%
'''
features:
- response_a_len, response_b_len
- len_diff
- promt_len
- lexical overlap of each response
   - measure of how many words are shared between two text samples
   - i.e. how many words in the original prompt are in the response
- semantic overlap of each response
   - measure of how similar the semantic meaning of two text samples are
   - i.e. how similar the meaning of the original prompt is to the response
- sentiment of each response compared to the original prompt
   - measure of the emotional tone of a text sample
   - i.e. how positive or negative the response is
   - use a pre-trained sentiment analysis model
   
potential features:
- topic coherence of each response compared to the original prompt
   - measure of how well the topics in a text sample are connected and coherent
   - i.e. how well the topics in the response are connected to the topics in the prompt
   - use a pre-trained topic coherence model
   
- 

'''
# Out:
# array(['gpt-4-1106-previewgpt-4-0613', 'koala-13bmistral-medium',
#        'gpt-3.5-turbo-0613mistral-7b-instruct',
#        'llama-2-13b-chatgpt-3.5-turbo-0314', 'vicuna-13bgpt-4-0314',
#        'mixtral-8x7b-instruct-v0.1vicuna-13b', 'gemini-proclaude-2.0',
#        'gpt-4-0314gpt-3.5-turbo-0613', 'vicuna-7bguanaco-33b',
#        'chatglm3-6bopenchat-3.5', 'pplx-70b-onlinegpt-3.5-turbo-1106',
#        'mpt-30b-chatgpt4all-13b-snoozy',
#        'llama2-70b-steerlm-chatkoala-13b', 'claude-1gemini-pro-dev-api',
#        'claude-2.1wizardlm-70b', 'chatglm-6bclaude-instant-1',
#        'claude-instant-1alpaca-13b', 'dolly-v2-12bgpt-4-0125-preview',
#        'claude-2.0wizardlm-13b',
#        'deepseek-llm-67b-chatgpt-4-1106-preview',
#        'openchat-3.5claude-2.1', 'starling-lm-7b-alphachatglm2-6b',
#        'gpt-4-0125-previewtulu-2-dpo-70b', 'llama-2-7b-chatclaude-1',
#        'gpt-4-0613zephyr-7b-beta', 'wizardlm-70bstarling-lm-7b-alpha',
# ...

# %%
# get percantage of the time each model won
